# %% [markdown]
# # SETTINGS

# %%
import pandas as pd
import emoji
from datetime import datetime
import numpy as np
import os

# %% [markdown]
# # CONFIGURATION

# %%
# CSV Settings
project_dir = r"C:\cache\Youtube-ETL_Project"
raw_dir = os.path.join(project_dir, "data", "raw")
latest_raw_path = os.path.join(raw_dir, "latest_raw_path.txt")

if os.path.exists(latest_raw_path):
    with open(latest_raw_path, "r", encoding="utf-8") as f:
        csv_files = f.read().strip()
else:
    raw_files = [
        os.path.join(raw_dir, file_name)
        for file_name in os.listdir(raw_dir)
        if file_name.startswith("raw_youtube_") and file_name.endswith(".csv")
    ]
    if not raw_files:
        raise FileNotFoundError(f"No raw CSV files found in: {raw_dir}")
    csv_files = max(raw_files, key=os.path.getmtime)

if not os.path.exists(csv_files):
    raise FileNotFoundError(f"Raw CSV not found: {csv_files}")

raw_file_name = os.path.basename(csv_files)
cleaned_file_name = raw_file_name.replace("raw_youtube_", "cleaned_youtube_", 1)

print("CSV file to process:", csv_files)
# Out:
# CSV file to process: c:\cache\Youtube-ETL_Project\data\raw\raw_youtube_Jul_2026.csv

# %% [markdown]
# # READ CSV

# %%
try:
    df = pd.read_csv(csv_files)
    print(f"Successfully read CSV files: {csv_files}, shape = {df.shape}")
    display(df.head(100))
    
    
except Exception as e:
    print(f"Error reading CSV files: {e}")
    raise
# Out:
# Successfully read CSV files: c:\cache\Youtube-ETL_Project\data\raw\raw_youtube_Jul_2026.csv, shape = (95, 16)
#        video_id                                        video_title  \
# 0   bNDeIcHbUtQ  How I got a Visa Sponsored Job in Germany from...
# 1   cd127O_lX80  Kornacki: Which states Democrats ‘have to win’...
# 2   ws0fI-X1xjg  Do not waste 2026 on the wrong career | AI Eng...
# 3   5O6ZLxmC5WE  Free Data Analytics Internship by Government o...
# 4   tTtI2arH214  Complete Data Analytics Portfolio Project | Le...
# ..          ...                                                ...
# 90  ebxQLpbnAM8  Work From Home Jobs 2026 | Data Analyst Jobs |...
# 91  FHvXKo5hYyE  How She Became a Data Analyst at Patanjali | I...
# 92  FgLBaty96Y4  DATA ANALYST vs. BUSINESS ANALYST | What's BES...
# 93  cZG-RVZjqjI  10 Biggest Myths About Data Analytics Explaine...
# 94  oME1r7dLGdc  Data Analyst Jobs for Freshers 2026 | Latest M...
#
#                   channel_id       channel_name  subscriber_count  \
# 0   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# 1   UCeY0bbntWzzVIaj2z3QigXg           NBC News          12100000
# 2   UCKOk1DiU3eUZV5CO0slBrMw       Akber Shaikh            112000
# 3   UCCn4rxyn0XVrSfR44aUwm4w       Heena Kouser             33100
# 4   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# ..                       ...                ...               ...
# 90  UCr_9-5VN4gneUznU_r7ZI6A  Earn With Kishore             28600
# 91  UC0T6MVd3wQDB5ICAe45OxaQ        WsCube Tech           4440000
# 92  UC_tgXLfHYVXFIe-8c4cRUNQ          Matt Mike             25900
# 93  UCDkox5NLaLtrYssKumtfzNA     Earners LAPTOP             57100
# 94  UCVKyjXbEKdU1yj35hlUvKPQ    Jobsearchguru4u             15800
#
#             publish_date                                    video_url  \
# 0   2026-07-20T10:30:27Z  https://www.youtube.com/watch?v=bNDeIcHbUtQ
# 1   2026-07-26T13:25:12Z  https://www.youtube.com/watch?v=cd127O_lX80
# 2   2026-07-03T12:30:33Z  https://www.youtube.com/watch?v=ws0fI-X1xjg
# 3   2026-07-08T06:30:18Z  https://www.youtube.com/watch?v=5O6ZLxmC5WE
# 4   2026-07-05T07:09:40Z  https://www.youtube.com/watch?v=tTtI2arH214
# ..                   ...                                          ...
# 90  2026-07-12T03:00:06Z  https://www.youtube.com/watch?v=ebxQLpbnAM8
# 91  2026-07-24T13:30:03Z  https://www.youtube.com/watch?v=FHvXKo5hYyE
# 92  2026-07-29T04:19:32Z  https://www.youtube.com/watch?v=FgLBaty96Y4
# 93  2026-07-24T12:31:42Z  https://www.youtube.com/watch?v=cZG-RVZjqjI
# 94  2026-07-18T08:31:34Z  https://www.youtube.com/watch?v=oME1r7dLGdc
#
#     duration  view_count  like_count  comment_count  \
# 0   00:30:16      304556        9103            866
# 1   00:04:35      259053        2774            737
# 2   00:09:50      192548        6217            375
# 3   00:00:51      161631        4778             53
# 4   02:43:11       79727        2994            266
# ..       ...         ...         ...            ...
# 90  00:04:22        3743          20              4
# 91  00:36:43        3664         101              9
# 92  00:14:45        3663         152              8
# 93  00:09:41        3639         164             24
# 94  00:17:20        3503         100             71
#
#                                                  tags              category  \
# 0   visa sponsored job in Germany|Germany job from...             Education
# 1   dc|election|government|meet the press|mtp|poli...       News & Politics
# 2   AI Engineer|ML Engineer|Data Scientist|AI Engi...             Education
# 3                                                 NaN             Education
# 4   data analyst project|data analysis project|dat...             Education
# ..                                                ...                   ...
# 90  data analyst jobs for freshers|work from home|...         Howto & Style
# 91  data analyst|data analyst interview|data analy...             Education
# 92  data|data analytics|analytics|analyst|data ana...  Science & Technology
# 93  data analytics|data analyst|data analytics myt...             Education
# 94  data analyst|data analyst jobs for fresher|dat...             Education
#
#                                        thumbnail_url       keyword  \
# 0   https://i.ytimg.com/vi/bNDeIcHbUtQ/hqdefault.jpg  data analyst
# 1   https://i.ytimg.com/vi/cd127O_lX80/hqdefault.jpg  data analyst
# 2   https://i.ytimg.com/vi/ws0fI-X1xjg/hqdefault.jpg  data analyst
# 3   https://i.ytimg.com/vi/5O6ZLxmC5WE/hqdefault.jpg  data analyst
# 4   https://i.ytimg.com/vi/tTtI2arH214/hqdefault.jpg  data analyst
# ..                                               ...           ...
# 90  https://i.ytimg.com/vi/ebxQLpbnAM8/hqdefault.jpg  data analyst
# 91  https://i.ytimg.com/vi/FHvXKo5hYyE/hqdefault.jpg  data analyst
# 92  https://i.ytimg.com/vi/FgLBaty96Y4/hqdefault.jpg  data analyst
# 93  https://i.ytimg.com/vi/cZG-RVZjqjI/hqdefault.jpg  data analyst
# 94  https://i.ytimg.com/vi/oME1r7dLGdc/hqdefault.jpg  data analyst
#
#    collection_date
# 0       2026-08-11
# 1       2026-08-11
# 2       2026-08-11
# 3       2026-08-11
# 4       2026-08-11
# ..             ...
# 90      2026-08-11
# 91      2026-08-11
# 92      2026-08-11
# 93      2026-08-11
# 94      2026-08-11
#
# [95 rows x 16 columns]

# %% [markdown]
# # DATA FIGURE

# %%
# Overview of the DataFrame
print("Shape:", df.shape)
print("\n--- Dtypes ---")
print(df.dtypes)
print("\n--- Info ---")
df.info()
# Out:
# Shape: (95, 16)
#
# --- Dtypes ---
# video_id              str
# video_title           str
# channel_id            str
# channel_name          str
# subscriber_count    int64
# publish_date          str
# video_url             str
# duration              str
# view_count          int64
# like_count          int64
# comment_count       int64
# tags                  str
# category              str
# thumbnail_url         str
# keyword               str
# collection_date       str
# dtype: object
#
# --- Info ---
# <class 'pandas.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   video_id          95 non-null     str
#  1   video_title       95 non-null     str
#  2   channel_id        95 non-null     str
#  3   channel_name      95 non-null     str
#  4   subscriber_count  95 non-null     int64
#  5   publish_date      95 non-null     str
#  6   video_url         95 non-null     str
#  7   duration          95 non-null     str
#  8   view_count        95 non-null     int64
#  9   like_count        95 non-null     int64
#  10  comment_count     95 non-null     int64
#  11  tags              79 non-null     str
#  12  category          95 non-null     str
#  13  thumbnail_url     95 non-null     str
#  14  keyword           95 non-null     str
#  15  collection_date   95 non-null     str
# dtypes: int64(4), str(12)
# memory usage: 12.0 KB

# %%
# 
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
print("Các cột số:", numeric_cols)
display(df[numeric_cols].describe())
# Out:
# Các cột số: ['subscriber_count', 'view_count', 'like_count', 'comment_count']
#        subscriber_count     view_count   like_count  comment_count
# count      9.500000e+01      95.000000    95.000000      95.000000
# mean       1.105196e+06   26379.947368   825.863158      82.936842
# std        3.050066e+06   47357.206603  1303.778124     148.016230
# min        5.070000e+02    3503.000000     0.000000       0.000000
# 25%        1.915000e+04    6388.000000   187.500000      14.000000
# 50%        5.710000e+04   11678.000000   364.000000      29.000000
# 75%        3.490000e+05   26771.500000   867.000000      72.500000
# max        1.330000e+07  304556.000000  9103.000000     866.000000

# %%
# Data Pivot Table - Viewcount by Video ID and Category
df.pivot_table(index='video_title', columns='category', values='view_count', aggfunc=np.sum, fill_value=0)
# Out:
# category                                            Education  Entertainment  \
# video_title
# (Official) Microsoft Free Data Analyst Certific...      30724              0
# 10 Biggest Myths About Data Analytics Explained...       3639              0
# 28 LPA+ Data Analyst Roadmap | Genpact Data Eng...      75818              0
# 9 LPA Data Analyst Jobs for Fresher | Foreign T...       4197              0
# AI in Data Analytics Explained | Tools, Use Cas...       3902              0
# ...                                                       ...            ...
# 🔥 TriNet Off-Campus Hiring | Remote Data Analyt...       6554              0
# 🔥How to Build a Data Analyst Portfolio That Get...      20469              0
# 🔥Most Asked SQL Interview Questions for Data An...      32317              0
# 🚀 Deloitte & HCLTech Mass Hiring 2026 | Data An...      14048              0
# 🤯 Stop Doing Manual Work in Excel! Create a Ful...          0              0
#
# category                                            Howto & Style  \
# video_title
# (Official) Microsoft Free Data Analyst Certific...              0
# 10 Biggest Myths About Data Analytics Explained...              0
# 28 LPA+ Data Analyst Roadmap | Genpact Data Eng...              0
# 9 LPA Data Analyst Jobs for Fresher | Foreign T...              0
# AI in Data Analytics Explained | Tools, Use Cas...              0
# ...                                                           ...
# 🔥 TriNet Off-Campus Hiring | Remote Data Analyt...              0
# 🔥How to Build a Data Analyst Portfolio That Get...              0
# 🔥Most Asked SQL Interview Questions for Data An...              0
# 🚀 Deloitte & HCLTech Mass Hiring 2026 | Data An...              0
# 🤯 Stop Doing Manual Work in Excel! Create a Ful...              0
#
# category                                            News & Politics  \
# video_title
# (Official) Microsoft Free Data Analyst Certific...                0
# 10 Biggest Myths About Data Analytics Explained...                0
# 28 LPA+ Data Analyst Roadmap | Genpact Data Eng...                0
# 9 LPA Data Analyst Jobs for Fresher | Foreign T...                0
# AI in Data Analytics Explained | Tools, Use Cas...                0
# ...                                                             ...
# 🔥 TriNet Off-Campus Hiring | Remote Data Analyt...                0
# 🔥How to Build a Data Analyst Portfolio That Get...                0
# 🔥Most Asked SQL Interview Questions for Data An...                0
# 🚀 Deloitte & HCLTech Mass Hiring 2026 | Data An...                0
# 🤯 Stop Doing Manual Work in Excel! Create a Ful...                0
#
# category                                            People & Blogs  \
# video_title
# (Official) Microsoft Free Data Analyst Certific...               0
# 10 Biggest Myths About Data Analytics Explained...               0
# 28 LPA+ Data Analyst Roadmap | Genpact Data Eng...               0
# 9 LPA Data Analyst Jobs for Fresher | Foreign T...               0
# AI in Data Analytics Explained | Tools, Use Cas...               0
# ...                                                            ...
# 🔥 TriNet Off-Campus Hiring | Remote Data Analyt...               0
# 🔥How to Build a Data Analyst Portfolio That Get...               0
# 🔥Most Asked SQL Interview Questions for Data An...               0
# 🚀 Deloitte & HCLTech Mass Hiring 2026 | Data An...               0
# 🤯 Stop Doing Manual Work in Excel! Create a Ful...            7650
#
# category                                            Science & Technology
# video_title
# (Official) Microsoft Free Data Analyst Certific...                     0
# 10 Biggest Myths About Data Analytics Explained...                     0
# 28 LPA+ Data Analyst Roadmap | Genpact Data Eng...                     0
# 9 LPA Data Analyst Jobs for Fresher | Foreign T...                     0
# AI in Data Analytics Explained | Tools, Use Cas...                     0
# ...                                                                  ...
# 🔥 TriNet Off-Campus Hiring | Remote Data Analyt...                     0
# 🔥How to Build a Data Analyst Portfolio That Get...                     0
# 🔥Most Asked SQL Interview Questions for Data An...                     0
# 🚀 Deloitte & HCLTech Mass Hiring 2026 | Data An...                     0
# 🤯 Stop Doing Manual Work in Excel! Create a Ful...                     0
#
# [95 rows x 6 columns]

# %%
df.groupby("channel_name")["subscriber_count"].count().sort_values(ascending=False).head(10)
# Out:
# channel_name
# Data Logic With Shivam                     8
# Intellipaat                                4
# Jobsearchguru4u                            4
# WsCube Tech                                4
# Lore So What                               4
# Earners LAPTOP                             3
# Heena Kouser                               3
# Mansi G.                                   3
# TOP Digital Professions | Sigma Academy    3
# Kedeisha Bryan - Your Data Career Coach    3
# Name: subscriber_count, dtype: int64

# %% [markdown]
# # CLEANING DATA

# %%
# Video title and tags cleaning emoji
df["video_title"] = df["video_title"].fillna("").apply(lambda x: emoji.replace_emoji(x, replace="").strip())
df["tags"] = df["tags"].fillna("").apply(lambda x: emoji.replace_emoji(x, replace="").strip())
df
# Out:
#        video_id                                        video_title  \
# 0   bNDeIcHbUtQ  How I got a Visa Sponsored Job in Germany from...
# 1   cd127O_lX80  Kornacki: Which states Democrats ‘have to win’...
# 2   ws0fI-X1xjg  Do not waste 2026 on the wrong career | AI Eng...
# 3   5O6ZLxmC5WE  Free Data Analytics Internship by Government o...
# 4   tTtI2arH214  Complete Data Analytics Portfolio Project | Le...
# ..          ...                                                ...
# 90  ebxQLpbnAM8  Work From Home Jobs 2026 | Data Analyst Jobs |...
# 91  FHvXKo5hYyE  How She Became a Data Analyst at Patanjali | I...
# 92  FgLBaty96Y4  DATA ANALYST vs. BUSINESS ANALYST | What's BES...
# 93  cZG-RVZjqjI  10 Biggest Myths About Data Analytics Explaine...
# 94  oME1r7dLGdc  Data Analyst Jobs for Freshers 2026 | Latest M...
#
#                   channel_id       channel_name  subscriber_count  \
# 0   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# 1   UCeY0bbntWzzVIaj2z3QigXg           NBC News          12100000
# 2   UCKOk1DiU3eUZV5CO0slBrMw       Akber Shaikh            112000
# 3   UCCn4rxyn0XVrSfR44aUwm4w       Heena Kouser             33100
# 4   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# ..                       ...                ...               ...
# 90  UCr_9-5VN4gneUznU_r7ZI6A  Earn With Kishore             28600
# 91  UC0T6MVd3wQDB5ICAe45OxaQ        WsCube Tech           4440000
# 92  UC_tgXLfHYVXFIe-8c4cRUNQ          Matt Mike             25900
# 93  UCDkox5NLaLtrYssKumtfzNA     Earners LAPTOP             57100
# 94  UCVKyjXbEKdU1yj35hlUvKPQ    Jobsearchguru4u             15800
#
#             publish_date                                    video_url  \
# 0   2026-07-20T10:30:27Z  https://www.youtube.com/watch?v=bNDeIcHbUtQ
# 1   2026-07-26T13:25:12Z  https://www.youtube.com/watch?v=cd127O_lX80
# 2   2026-07-03T12:30:33Z  https://www.youtube.com/watch?v=ws0fI-X1xjg
# 3   2026-07-08T06:30:18Z  https://www.youtube.com/watch?v=5O6ZLxmC5WE
# 4   2026-07-05T07:09:40Z  https://www.youtube.com/watch?v=tTtI2arH214
# ..                   ...                                          ...
# 90  2026-07-12T03:00:06Z  https://www.youtube.com/watch?v=ebxQLpbnAM8
# 91  2026-07-24T13:30:03Z  https://www.youtube.com/watch?v=FHvXKo5hYyE
# 92  2026-07-29T04:19:32Z  https://www.youtube.com/watch?v=FgLBaty96Y4
# 93  2026-07-24T12:31:42Z  https://www.youtube.com/watch?v=cZG-RVZjqjI
# 94  2026-07-18T08:31:34Z  https://www.youtube.com/watch?v=oME1r7dLGdc
#
#     duration  view_count  like_count  comment_count  \
# 0   00:30:16      304556        9103            866
# 1   00:04:35      259053        2774            737
# 2   00:09:50      192548        6217            375
# 3   00:00:51      161631        4778             53
# 4   02:43:11       79727        2994            266
# ..       ...         ...         ...            ...
# 90  00:04:22        3743          20              4
# 91  00:36:43        3664         101              9
# 92  00:14:45        3663         152              8
# 93  00:09:41        3639         164             24
# 94  00:17:20        3503         100             71
#
#                                                  tags              category  \
# 0   visa sponsored job in Germany|Germany job from...             Education
# 1   dc|election|government|meet the press|mtp|poli...       News & Politics
# 2   AI Engineer|ML Engineer|Data Scientist|AI Engi...             Education
# 3                                                                 Education
# 4   data analyst project|data analysis project|dat...             Education
# ..                                                ...                   ...
# 90  data analyst jobs for freshers|work from home|...         Howto & Style
# 91  data analyst|data analyst interview|data analy...             Education
# 92  data|data analytics|analytics|analyst|data ana...  Science & Technology
# 93  data analytics|data analyst|data analytics myt...             Education
# 94  data analyst|data analyst jobs for fresher|dat...             Education
#
#                                        thumbnail_url       keyword  \
# 0   https://i.ytimg.com/vi/bNDeIcHbUtQ/hqdefault.jpg  data analyst
# 1   https://i.ytimg.com/vi/cd127O_lX80/hqdefault.jpg  data analyst
# 2   https://i.ytimg.com/vi/ws0fI-X1xjg/hqdefault.jpg  data analyst
# 3   https://i.ytimg.com/vi/5O6ZLxmC5WE/hqdefault.jpg  data analyst
# 4   https://i.ytimg.com/vi/tTtI2arH214/hqdefault.jpg  data analyst
# ..                                               ...           ...
# 90  https://i.ytimg.com/vi/ebxQLpbnAM8/hqdefault.jpg  data analyst
# 91  https://i.ytimg.com/vi/FHvXKo5hYyE/hqdefault.jpg  data analyst
# 92  https://i.ytimg.com/vi/FgLBaty96Y4/hqdefault.jpg  data analyst
# 93  https://i.ytimg.com/vi/cZG-RVZjqjI/hqdefault.jpg  data analyst
# 94  https://i.ytimg.com/vi/oME1r7dLGdc/hqdefault.jpg  data analyst
#
#    collection_date
# 0       2026-08-11
# 1       2026-08-11
# 2       2026-08-11
# 3       2026-08-11
# 4       2026-08-11
# ..             ...
# 90      2026-08-11
# 91      2026-08-11
# 92      2026-08-11
# 93      2026-08-11
# 94      2026-08-11
#
# [95 rows x 16 columns]

# %%
# Duration categorization
df["duration_seconds"] = pd.to_timedelta(df["duration"]).dt.total_seconds().astype(int)

conditions1 = [
    df["duration_seconds"] >= 3600,
    df["duration_seconds"] >= 1800,
    df["duration_seconds"] >= 300,
]
choices1 = [
    "Long Video (1 hour or more)",
    "Medium Video (30-60 minutes)",
    "Short Video (5-30 minutes)",
]
df["duration_category"] = np.select(conditions1, choices1, default="Very Short Video (Less than 5 minutes)")
df
# Out:
#        video_id                                        video_title  \
# 0   bNDeIcHbUtQ  How I got a Visa Sponsored Job in Germany from...
# 1   cd127O_lX80  Kornacki: Which states Democrats ‘have to win’...
# 2   ws0fI-X1xjg  Do not waste 2026 on the wrong career | AI Eng...
# 3   5O6ZLxmC5WE  Free Data Analytics Internship by Government o...
# 4   tTtI2arH214  Complete Data Analytics Portfolio Project | Le...
# ..          ...                                                ...
# 90  ebxQLpbnAM8  Work From Home Jobs 2026 | Data Analyst Jobs |...
# 91  FHvXKo5hYyE  How She Became a Data Analyst at Patanjali | I...
# 92  FgLBaty96Y4  DATA ANALYST vs. BUSINESS ANALYST | What's BES...
# 93  cZG-RVZjqjI  10 Biggest Myths About Data Analytics Explaine...
# 94  oME1r7dLGdc  Data Analyst Jobs for Freshers 2026 | Latest M...
#
#                   channel_id       channel_name  subscriber_count  \
# 0   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# 1   UCeY0bbntWzzVIaj2z3QigXg           NBC News          12100000
# 2   UCKOk1DiU3eUZV5CO0slBrMw       Akber Shaikh            112000
# 3   UCCn4rxyn0XVrSfR44aUwm4w       Heena Kouser             33100
# 4   UC3rY5HOgbBvGmq7RnDfwF7A     Rishabh Mishra            575000
# ..                       ...                ...               ...
# 90  UCr_9-5VN4gneUznU_r7ZI6A  Earn With Kishore             28600
# 91  UC0T6MVd3wQDB5ICAe45OxaQ        WsCube Tech           4440000
# 92  UC_tgXLfHYVXFIe-8c4cRUNQ          Matt Mike             25900
# 93  UCDkox5NLaLtrYssKumtfzNA     Earners LAPTOP             57100
# 94  UCVKyjXbEKdU1yj35hlUvKPQ    Jobsearchguru4u             15800
#
#             publish_date                                    video_url  \
# 0   2026-07-20T10:30:27Z  https://www.youtube.com/watch?v=bNDeIcHbUtQ
# 1   2026-07-26T13:25:12Z  https://www.youtube.com/watch?v=cd127O_lX80
# 2   2026-07-03T12:30:33Z  https://www.youtube.com/watch?v=ws0fI-X1xjg
# 3   2026-07-08T06:30:18Z  https://www.youtube.com/watch?v=5O6ZLxmC5WE
# 4   2026-07-05T07:09:40Z  https://www.youtube.com/watch?v=tTtI2arH214
# ..                   ...                                          ...
# 90  2026-07-12T03:00:06Z  https://www.youtube.com/watch?v=ebxQLpbnAM8
# 91  2026-07-24T13:30:03Z  https://www.youtube.com/watch?v=FHvXKo5hYyE
# 92  2026-07-29T04:19:32Z  https://www.youtube.com/watch?v=FgLBaty96Y4
# 93  2026-07-24T12:31:42Z  https://www.youtube.com/watch?v=cZG-RVZjqjI
# 94  2026-07-18T08:31:34Z  https://www.youtube.com/watch?v=oME1r7dLGdc
#
#     duration  view_count  like_count  comment_count  \
# 0   00:30:16      304556        9103            866
# 1   00:04:35      259053        2774            737
# 2   00:09:50      192548        6217            375
# 3   00:00:51      161631        4778             53
# 4   02:43:11       79727        2994            266
# ..       ...         ...         ...            ...
# 90  00:04:22        3743          20              4
# 91  00:36:43        3664         101              9
# 92  00:14:45        3663         152              8
# 93  00:09:41        3639         164             24
# 94  00:17:20        3503         100             71
#
#                                                  tags              category  \
# 0   visa sponsored job in Germany|Germany job from...             Education
# 1   dc|election|government|meet the press|mtp|poli...       News & Politics
# 2   AI Engineer|ML Engineer|Data Scientist|AI Engi...             Education
# 3                                                                 Education
# 4   data analyst project|data analysis project|dat...             Education
# ..                                                ...                   ...
# 90  data analyst jobs for freshers|work from home|...         Howto & Style
# 91  data analyst|data analyst interview|data analy...             Education
# 92  data|data analytics|analytics|analyst|data ana...  Science & Technology
# 93  data analytics|data analyst|data analytics myt...             Education
# 94  data analyst|data analyst jobs for fresher|dat...             Education
#
#                                        thumbnail_url       keyword  \
# 0   https://i.ytimg.com/vi/bNDeIcHbUtQ/hqdefault.jpg  data analyst
# 1   https://i.ytimg.com/vi/cd127O_lX80/hqdefault.jpg  data analyst
# 2   https://i.ytimg.com/vi/ws0fI-X1xjg/hqdefault.jpg  data analyst
# 3   https://i.ytimg.com/vi/5O6ZLxmC5WE/hqdefault.jpg  data analyst
# 4   https://i.ytimg.com/vi/tTtI2arH214/hqdefault.jpg  data analyst
# ..                                               ...           ...
# 90  https://i.ytimg.com/vi/ebxQLpbnAM8/hqdefault.jpg  data analyst
# 91  https://i.ytimg.com/vi/FHvXKo5hYyE/hqdefault.jpg  data analyst
# 92  https://i.ytimg.com/vi/FgLBaty96Y4/hqdefault.jpg  data analyst
# 93  https://i.ytimg.com/vi/cZG-RVZjqjI/hqdefault.jpg  data analyst
# 94  https://i.ytimg.com/vi/oME1r7dLGdc/hqdefault.jpg  data analyst
#
#    collection_date  duration_seconds                       duration_category
# 0       2026-08-11              1816            Medium Video (30-60 minutes)
# 1       2026-08-11               275  Very Short Video (Less than 5 minutes)
# 2       2026-08-11               590              Short Video (5-30 minutes)
# 3       2026-08-11                51  Very Short Video (Less than 5 minutes)
# 4       2026-08-11              9791             Long Video (1 hour or more)
# ..             ...               ...                                     ...
# 90      2026-08-11               262  Very Short Video (Less than 5 minutes)
# 91      2026-08-11              2203            Medium Video (30-60 minutes)
# 92      2026-08-11               885              Short Video (5-30 minutes)
# 93      2026-08-11               581              Short Video (5-30 minutes)
# 94      2026-08-11              1040              Short Video (5-30 minutes)
#
# [95 rows x 18 columns]

# %%
# Month, Day, Year extraction
try:
    df["day_cleaned"] = pd.to_datetime(df["publish_date"]).dt.day
    df["month_cleaned"] = pd.to_datetime(df["publish_date"]).dt.month
    df["year_cleaned"] = pd.to_datetime(df["publish_date"]).dt.year
except Exception as e:
    print(f"Error processing publish_date: {e}")
    raise

# %% [markdown]
# # RESULT

# %%
# Save the cleaned DataFrame to a new CSV file
cleaned_dir = r"C:\cache\Youtube-ETL_Project\data\cleaned"

os.makedirs(cleaned_dir, exist_ok=True)

cleaned_path = os.path.join(cleaned_dir, cleaned_file_name)

df.to_csv(cleaned_path, index=False, encoding="utf-8-sig")

latest_cleaned_path = f"{cleaned_dir}\\latest_cleaned_path.txt"
with open(latest_cleaned_path, "w", encoding="utf-8") as f:
    f.write(cleaned_path)

print(f"✅ Đã lưu: {cleaned_path} | shape = {df.shape}")
print(f"Latest cleaned path saved to: {latest_cleaned_path}")
# Out:
# ✅ Đã lưu: C:\cache\Youtube-ETL_Project\data\cleaned\cleaned_youtube_Jul_2026.csv | shape = (95, 21)
# Latest cleaned path saved to: C:\cache\Youtube-ETL_Project\data\cleaned\latest_cleaned_path.txt
